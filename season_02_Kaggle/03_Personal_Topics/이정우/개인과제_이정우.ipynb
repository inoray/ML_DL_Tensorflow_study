# %% [markdown]
# 2018.07.19 이정우
#
# # **선정 주제: Denoising**

# %% [markdown]
# # **목표: **
#
#
# *   딥러닝을 활용한 Denoising 방안에 대한 검토
# *   방안 별 테스트 및 적용/개선 방안 도출

# %% [markdown]
# # **일정: **
#
#
# *   중간 발표일 : 8월 23일
# *   최종 발표일:  9월 21일
#   (9월 말까지 R&D 2건이 잡혀 있어, 딜레이 발생 할 수 있음)

# %% [markdown]
# # *검색된 방안 후보군:*

# %% [markdown]
#  - AutoEncorder를 이용한 방안
#
#     ![대체 텍스트](
#      https://cdn-images-1.medium.com/max/1600/1*ZyXnDR8yWrKvaVhDczx0VQ.png)
#
#
#  - DWT (discrete wavelet transform) 를 이용한 방안
#
#     ![대체 텍스트](https://2.bp.blogspot.com/-PWixX2Oy3VY/V17TOWJOUHI/AAAAAAAAA88/pWWKfffgCCIy7xHHUflVv9YWplhtWGA_gCLcB/s640/denoise_1.png)
